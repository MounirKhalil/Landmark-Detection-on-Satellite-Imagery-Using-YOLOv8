# %%
from ultralytics import YOLO

# we load our best trained model till now
model = YOLO('xView\\YoloTrainingOutput\\train17\\weights\\best.pt')

# we define path to the image/video file  --- the output will be in 'runs\detect' folder
source = 'google_earth\\a.mp4'   # THIS IS A VIDEO
# source = 'google_earth\\test1.jpg'   # THIS IS AN IMAGE

model.predict(source, save=True, imgsz=1200, conf=0.5)
# Out:
# WARNING  imgsz=[1200] must be multiple of max stride 32, updating to [1216]
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/334) c:\eece490proj\google_earth\a.mp4: 768x1216 7 Cargo Planes, 2 Buildings, 112.1ms
# video 1/1 (frame 2/334) c:\eece490proj\google_earth\a.mp4: 768x1216 7 Cargo Planes, 2 Buildings, 22.0ms
# video 1/1 (frame 3/334) c:\eece490proj\google_earth\a.mp4: 768x1216 7 Cargo Planes, 2 Buildings, 23.0ms
# ...
